# %%
import tweepy

# %%
# Fill the X's with the credentials obtained by  
# following the above mentioned procedure. 
consumer_key = "Ldr8zd96MGYJYGS1mIcUadzpY " 
consumer_secret = "UhKLxlm0uoahVJJf0DSrjZzmPmTmi3W7DoAD1Y2MwwnFJw8wms"
access_key = "860425611902431232-QxX0h9QGwsxS2Ti22GnGEBI5UFN1cWE"
access_secret = "uUCySL8BbtTE8E5Qlm1xXSlFoxh1DV0HVHwzI2nDeypAq "

# %%
def get_tweets(username): 
          
         
        auth = tweepy.OAuthHandler("Ldr8zd96MGYJYGS1mIcUadzpY","UhKLxlm0uoahVJJf0DSrjZzmPmTmi3W7DoAD1Y2MwwnFJw8wms") 
        auth.set_access_token("860425611902431232-QxX0h9QGwsxS2Ti22GnGEBI5UFN1cWE","uUCySL8BbtTE8E5Qlm1xXSlFoxh1DV0HVHwzI2nDeypAq")  
        api = tweepy.API(auth) 
        number_of_tweets=20
        tweets = api.user_timeline(screen_name=username) 
        tmp=[]  
        tweets_for_csv = [tweet.text for tweet in tweets] # CSV file created  
        for j in tweets_for_csv: 
            tmp.append(j) 
            print(tmp)
            if __name__ == '__main__':
                get_tweets("midasIIITD")

# %%
get_tweets("midasIIITD")
# Out:
# ['@midasIIITD lab is looking for motivated MTech @IIITDelhi students who are interested in doing their thesis in #NLP… https://t.co/0MMf7euBVv']
# ['@midasIIITD lab is looking for motivated MTech @IIITDelhi students who are interested in doing their thesis in #NLP… https://t.co/0MMf7euBVv']
# ['@midasIIITD lab is looking for motivated MTech @IIITDelhi students who are interested in doing their thesis in #NLP… https://t.co/0MMf7euBVv']
# ['@midasIIITD lab is looking for motivated MTech @IIITDelhi students who are interested in doing their thesis in #NLP… https://t.co/0MMf7euBVv']
# ['@midasIIITD lab is looking for motivated MTech @IIITDelhi students who are interested in doing their thesis in #NLP… https://t.co/0MMf7euBVv']
# ['@midasIIITD lab is looking for motivated MTech @IIITDelhi students who are interested in doing their thesis in #NLP… https://t.co/0MMf7euBVv']
# ...

# %%
###### 200 tweets to be extracted 
        number_of_tweets=200
        tweets = api.user_timeline(screen_name=midasIIITD)

# %%
import tweepy
from tweepy import OAuthHandler
import json
import datetime as dt
import time
import os
import sys

# %%
ef load_api():
    ''' Function that loads the twitter API after authorizing the user. '''

    consumer_key = 'Ldr8zd96MGYJYGS1mIcUadzpY'
    consumer_secret = 'UhKLxlm0uoahVJJf0DSrjZzmPmTmi3W7DoAD1Y2MwwnFJw8wms'
    access_token = '860425611902431232-QxX0h9QGwsxS2Ti22GnGEBI5UFN1cWE'
    access_secret = 'uUCySL8BbtTE8E5Qlm1xXSlFoxh1DV0HVHwzI2nDeypAq'
    auth = OAuthHandler(Ldr8zd96MGYJYGS1mIcUadzpY, UhKLxlm0uoahVJJf0DSrjZzmPmTmi3W7DoAD1Y2MwwnFJw8wms)
    auth.set_access_token(860425611902431232-QxX0h9QGwsxS2Ti22GnGEBI5UFN1cWE, uUCySL8BbtTE8E5Qlm1xXSlFoxh1DV0HVHwzI2nDeypAq)

    api = tweepy.API(auth, wait_on_rate_limit=True)

    # load the twitter API via tweepy
    return tweepy.API(auth)
# Out:
#   File "<ipython-input-19-4e36b8f0954d>", line 1
#     ef load_api():
#               ^
# SyntaxError: invalid syntax
